# %%
from stitching import *

# %%
fix_filenames(r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\532")
# Out:
# Scanning: G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\532 ...
#
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V1H1_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_000_concat.tif
# Error renaming 2x_532nm_200ms_3.25x3.25x3.25um_V1H2_concat.tif: [WinError 183] Cannot create a file when that file already exists: 'G:\\Ding Lab Images\\Sample_4_112525\\Ding Lab 11-13\\2x\\532\\2x_532nm_200ms_3.25x3.25x3.25um_V1H2_concat.tif' -> 'G:\\Ding Lab Images\\Sample_4_112525\\Ding Lab 11-13\\2x\\532\\2x_532nm_200ms_3.25x3.25x3.25um_tile_001_concat.tif'
#
# Success! Processed 2 files.
# (True, 2)

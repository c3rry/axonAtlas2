# %% [markdown]
# # helper functions

# %%
from auxilary import tiffVisualize, run_command_line, createExperiment
from processing import binarize, dimCompose, threshold, skeletonize
from segmentation import check_trailmap, stackToFolder, folderToStack, axonSegment
from registration import Registration, regExtract

# %% [markdown]
# # getting started!
# here we will install the TrailMap axon segmentation model if nesscary and create our expirement

# %%
check_trailmap()
exp_path = createExperiment("alpha")
#exp_path = r"F:\axonAtlas2\experiments\realDataTest_2025-06-17_15-22-57"
axon_stack = r"F:\13377319\Liu_anatomy_data_code\TrailMap\AL211_647\AL211_647.tif"
autof_stack = r""
cell_stack = r""
tiffVisualize(axon_stack, views=3, colormap="turbo")
# Out:
# <tifffile.TiffPage 0 @8> imagej_metadata failed with ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# The folder 'TRAILMAP' was found in the current directory. Proceed!
# Ensured base experiments directory exists: 'F:\axonAtlas2\experiments'
# Successfully created experiment folder: 'F:\axonAtlas2\experiments\alpha_2025-06-18_15-59-58'
# Warning: 'F:\13377319\Liu_anatomy_data_code\TrailMap\AL211_647\AL211_647.tif' is not a multi-page TIFF. Visualizing as a single image.
# Successfully visualized 'F:\13377319\Liu_anatomy_data_code\TrailMap\AL211_647\AL211_647.tif'.

# %% [markdown]
# # axon segmentation
# here we will run trailmap and generate our axon segmentation masks

# %%
seg_axon_stack = axonSegment(axon_stack, exp_path)
#seg_axon_stack = r"F:\axonAtlas2\experiments\realDataTest_2025-06-17_15-22-57\seg-AL211_647.tif"
tiffVisualize(seg_axon_stack, views=3, colormap="turbo")
# Out:
# Found existing installation: h5py 3.8.0
# Uninstalling h5py-3.8.0:
#   Successfully uninstalled h5py-3.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# morphio 3.3.6 requires h5py<4,>=3, but you have h5py 2.10.0 which is incompatible.
# <tifffile.TiffPage 0 @8> imagej_metadata failed with ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Collecting h5py==2.10.0
#   Using cached h5py-2.10.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\trailmap_env\lib\site-packages (from h5py==2.10.0) (1.16.0)
# Requirement already satisfied: numpy>=1.7 in c:\programdata\anaconda3\envs\trailmap_env\lib\site-packages (from h5py==2.10.0) (1.21.5)
# Installing collected packages: h5py
# Successfully installed h5py-2.10.0
#
# --- Starting TRAILMAP Inference for 'AL211_647.tif' ---
# Created temporary directory: 'F:\axonAtlas2\experiments\alpha_2025-06-18_15-59-58\trailmap_inference_temp'
#
# Converting 'AL211_647.tif' to frames folder...
# Created output folder: 'F:\axonAtlas2\experiments\alpha_2025-06-18_15-59-58\trailmap_inference_temp\AL211_647_folder'
# Processing 1436 frames from 'F:\13377319\Liu_anatomy_data_code\TrailMap\AL211_647\AL211_647.tif'...
# Successfully saved all frames from 'F:\13377319\Liu_anatomy_data_code\TrailMap\AL211_647\AL211_647.tif' to 'F:\axonAtlas2\experiments\alpha_2025-06-18_15-59-58\trailmap_inference_temp\AL211_647_folder'.
#
# Running TRAILMAP segmentation command...
# Command executed: 'python TRAILMAP/segment_brain_batch.py F:/axonAtlas2/experiments/alpha_2025-06-18_15-59-58/trailmap_inference_temp/AL211_647_folder'
# Return Code: 1
# STDOUT:
# Name: AL211_647_folder
#
# [                                        ]   0%       ETA: Pending
# [                                        ]   0%       ETA: 220.3 mins
# [=                                       ]   3%       ETA: 89.5 mins
# [==                                      ]   5%       ETA: 58.8 mins
# STDERR:
# 2025-06-18 16:03:11.745475: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2025-06-18 16:03:13.635623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2025-06-18 16:03:13.725609: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:51:00.0 name: NVIDIA RTX A4500 computeCapability: 8.6
# coreClock: 1.65GHz coreCount: 56 deviceMemorySize: 19.99GiB deviceMemoryBandwidth: 596.12GiB/s
# 2025-06-18 16:03:13.725633: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2025-06-18 16:03:13.729007: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_10.dll
# 2025-06-18 16:03:13.731622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_10.dll
# 2025-06-18 16:03:13.732594: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_10.dll
# 2025-06-18 16:03:13.735514: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_10.dll
# 2025-06-18 16:03:13.737335: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_10.dll
# 2025-06-18 16:03:13.743666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2025-06-18 16:03:13.743721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2025-06-18 16:03:13.744129: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2025-06-18 16:03:13.750731: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:51:00.0 name: NVIDIA RTX A4500 computeCapability: 8.6
# coreClock: 1.65GHz coreCount: 56 deviceMemorySize: 19.99GiB deviceMemoryBandwidth: 596.12GiB/s
# 2025-06-18 16:03:13.750751: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2025-06-18 16:03:13.750757: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_10.dll
# 2025-06-18 16:03:13.750761: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cufft64_10.dll
# 2025-06-18 16:03:13.750765: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library curand64_10.dll
# 2025-06-18 16:03:13.750769: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusolver64_10.dll
# 2025-06-18 16:03:13.750774: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cusparse64_10.dll
# 2025-06-18 16:03:13.750778: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2025-06-18 16:03:13.750793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1697] Adding visible gpu devices: 0
# 2025-06-18 16:03:14.841572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1096] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-06-18 16:03:14.841595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102]      0
# 2025-06-18 16:03:14.841601: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] 0:   N
# 2025-06-18 16:03:14.841706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1241] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 18240 MB memory) -> physical GPU (device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:51:00.0, compute capability: 8.6)
# 2025-06-18 16:03:18.203010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudnn64_7.dll
# 2025-06-18 16:05:39.987258: W tensorflow/stream_executor/gpu/redzone_allocator.cc:312] Internal: Invoking GPU asm compilation is supported on Cuda non-Windows platforms only
# Relying on driver to perform ptx compilation. This message will be only logged once.
# 2025-06-18 16:05:40.346931: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_10.dll
# Traceback (most recent call last):
#   File "TRAILMAP/segment_brain_batch.py", line 43, in <module>
#     segment_brain(input_folder, output_folder, model)
#   File "F:\axonAtlas2\TRAILMAP\inference\segment_brain.py", line 130, in segment_brain
#     write_folder_section(output_folder, file_names, section_index, section_seg)
#   File "F:\axonAtlas2\TRAILMAP\inference\segment_brain.py", line 76, in write_folder_section
#     pil_image.save(output_full_path)
#   File "C:\ProgramData\anaconda3\envs\trailmap_env\lib\site-packages\PIL\Image.py", line 2432, in save
#     save_handler(self, fp, filename)
#   File "C:\ProgramData\anaconda3\envs\trailmap_env\lib\site-packages\PIL\TiffImagePlugin.py", line 1871, in _save
#     im, fp, [("raw", (0, 0) + im.size, offset, (rawmode, stride, 1))]
#   File "C:\ProgramData\anaconda3\envs\trailmap_env\lib\site-packages\PIL\ImageFile.py", line 517, in _save
#     _encode_tile(im, fp, tile, bufsize, fh)
#   File "C:\ProgramData\anaconda3\envs\trailmap_env\lib\site-packages\PIL\ImageFile.py", line 544, in _encode_tile
#     errcode = encoder.encode_to_file(fh, bufsize)
# OSError: [Errno 28] No space left on device
#
# TRAILMAP segmentation command failed with error code 1. Check STDERR above.
# Please ensure TRAILMAP is correctly installed and its 'segment_brain_batch.py' script is accessible.
# Also verify the input folder format expected by TRAILMAP.
# Cleaned up 'F:\axonAtlas2\experiments\alpha_2025-06-18_15-59-58\trailmap_inference_temp\AL211_647_folder'.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34272\1947706933.py in <module>
#       3 seg_axon_stack = axonSegment(axon_stack, exp_path)
#       4 #seg_axon_stack = r"F:\axonAtlas2\experiments\realDataTest_2025-06-17_15-22-57\seg-AL211_647.tif"
# ----> 5 tiffVisualize(seg_axon_stack, views=3, colormap="turbo")
#
# F:\axonAtlas2\auxilary.py in tiffVisualize(file_path, views, colormap, contrast_factor, brightness_factor)
#      27                                    Defaults to 0.0 (no change).
#      28     """
# ---> 29     if not os.path.exists(file_path):
#      30         print(f"Error: File not found at '{file_path}'")
#      31         return
#
# C:\ProgramData\anaconda3\envs\trailmap_env\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %% [markdown]
# # composition
# here we binarize our segmentation masks and compose them with the raw axonal data to prepare for registration|

# %%
binary = binarize(seg_axon_stack, exp_path)
axon_proc = dimCompose(binary, axon_stack, exp_path, dim_factor = 0.5)
tiffVisualize(axon_proc, views=3, colormap="bone")

# %% [markdown]
# # registration
# here we register our autoflourescence and composed data to the allen mouse brain atlas

# %%
reg_path = Registration(autof_path=axon_proc, v1=10, v2=10, v3=10, orientation="sal", output_dir=exp_path, atlas="allen_mouse_25um")
#reg_path = r"F:\axonAtlas2\experiments\realDataTest_2025-06-17_15-22-57\registration"

# %%
reg_list = regExtract(reg_path)
print(reg_list)
downsampled_standard_autof = reg_list[3]
tiffVisualize(downsampled_standard_autof, views=3, colormap="bone")

# %% [markdown]
# # postprocessing
# here we use thresholding to extract the exon segmentation masks in the atlas space

# %%
downsampled_standard_autof_threshold = threshold(downsampled_standard_autof, exp_path, threshold = 200)
tiffVisualize(downsampled_standard_autof_threshold, views=3, colormap="bone")

# %%
downsampled_standard_autof_skeleton = skeletonize(downsampled_standard_autof_threshold, exp_path)
tiffVisualize(downsampled_standard_autof_skeleton, views=3, colormap="bone")

# %% [markdown]
# # congrats! you finished part1 switch from the trailmmap_env to the BrainRender and then move over to the visualization notebook to turn these into 3D

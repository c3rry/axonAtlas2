# %%
from visualization import modeExtract, sanitize_filename, volume3D, topNRegions, screenshotExtract
from vedo import embedWindow

embedWindow(None)
# Out:
# embedWindow(verbose=True): could not load ipyvtklink try:
# > pip install ipyvtklink

# %%
exp_path = r"F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23"
#volume = modeExtract(exp_path, mode="skeletonize")
volume = exp_path + "\downsampled_standard_binned_tiffs\combined_top_5_skeletonize.tif"
#volume = r"F:\axonAtlas2\experiments\UTSW_brain8_reg_optim_2025-11-11_12-39-20\cluster_016_connected.tif"
print(volume)
# Out:
# F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23\downsampled_standard_binned_tiffs\combined_top_5_skeletonize.tif

# %%
volume3D(
    input_volume=volume,
    temp_dir=r"C:\Users\gangliagurdian\Downloads\temp",
    voxel_size=25,
    #colormaps=["Reds", "Blues", "Greens", "Oranges", "Purples"],
    #regions=["PO", "GPe", "CTX", "VPM", "MD"],
    colormaps = ["gray"],
    regions = ["grey"],
    output_dir=exp_path
)
# Out:
# [INFO] Starting volume3D with input_volume:
# F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23\downsampled_standard_binned_tiffs\combined_top_
# 5_skeletonize.tif
# [INFO] Temporary directory created at: C:\Users\gangliagurdian\Downloads\temp
# [INFO] Output directory created at: F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23
# [INFO] Screenshots will be saved in:
# F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23\3dscreenshoots
# [INFO] Using provided colormaps: ['gray']
# [INFO] Detected input file extension: .tif
# [INFO] Loading TIFF file:
# F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23\downsampled_standard_binned_tiffs\combined_top_
# 5_skeletonize.tif
# [INFO] Loaded input data with shape: (528, 320, 456) and dtype: uint8
# [INFO] Saving input data as NIfTI to: C:\Users\gangliagurdian\Downloads\temp\image1.nii.gz
# ...

# %%
screenshotExtract(exp_path)
# Out:
# [INFO] Found 3 PNG files in F:\axonAtlas2\experiments\UTSW_brain5_reg_optim_2025-11-15_17-28-23\3dscreenshoots.
# Displaying images...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1500x500 with 3 Axes>

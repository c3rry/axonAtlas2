# %%
from pathlib import Path
import sys

current_dir = Path.cwd()
parent_dir = current_dir.parent
sys.path.append(str(parent_dir))

# %%
from lib.stitching import *

# %%
preprocessing(r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x_532nm", r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x\532")
# Out:
# Scanning G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x_532nm...
# Processing group: 4x_532nm_20ms_1.625x1.625x1.625um_V1H1 (8 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x\532\4x_532nm_20ms_1.625x1.625x1.625um_V1H1_concat.tif
# Processing group: 4x_532nm_20ms_1.625x1.625x1.625um_V1H2 (8 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x\532\4x_532nm_20ms_1.625x1.625x1.625um_V1H2_concat.tif
# Processing group: 4x_532nm_20ms_1.625x1.625x1.625um_V1H3 (9 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x\532\4x_532nm_20ms_1.625x1.625x1.625um_V1H3_concat.tif
# Processing group: 4x_532nm_20ms_1.625x1.625x1.625um_V1H4 (8 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\4x\532\4x_532nm_20ms_1.625x1.625x1.625um_V1H4_concat.tif
# Processing group: 4x_532nm_20ms_1.625x1.625x1.625um_V2H1 (9 parts)
# ...

# %%
fix_filenames(r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\532")
# Out:
# Scanning: G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\532 ...
#
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V1H1_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_000_concat.tif
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V1H2_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_001_concat.tif
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V2H1_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_002_concat.tif
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V2H2_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_003_concat.tif
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V3H1_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_004_concat.tif
# Renamed: 2x_532nm_200ms_3.25x3.25x3.25um_V3H2_concat.tif
#      ->  2x_532nm_200ms_3.25x3.25x3.25um_tile_005_concat.tif
#
# Success! Processed 6 files.
# (True, 6)

# %%
preprocessing(r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2X_473nm", r"G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\473")
# Out:
# Scanning G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2X_473nm...
# Processing group: 2x_473nm_200ms_3.25x3.25x3.25um_V1H1 (5 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\473\2x_473nm_200ms_3.25x3.25x3.25um_V1H1_concat.tif
# Processing group: 2x_473nm_200ms_3.25x3.25x3.25um_V1H2 (5 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\473\2x_473nm_200ms_3.25x3.25x3.25um_V1H2_concat.tif
# Processing group: 2x_473nm_200ms_3.25x3.25x3.25um_V2H1 (5 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\473\2x_473nm_200ms_3.25x3.25x3.25um_V2H1_concat.tif
# Processing group: 2x_473nm_200ms_3.25x3.25x3.25um_V2H2 (5 parts)
#   -> Saved to G:\Ding Lab Images\Sample_4_112525\Ding Lab 11-13\2x\473\2x_473nm_200ms_3.25x3.25x3.25um_V2H2_concat.tif
# Processing group: 2x_473nm_200ms_3.25x3.25x3.25um_V3H1 (5 parts)
# ...

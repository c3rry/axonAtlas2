# %%
import os

current_dir = os.getcwd()
print(f"Current directory: {current_dir}") 

os.chdir("..")

new_dir = os.getcwd()
print(f"New directory: {new_dir}")
# Out:
# Current directory: f:\axonAtlas2\notebooks
# New directory: f:\axonAtlas2

# %%
from lib.post_stitch import *

consolidate_channels(r"Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7")
# Out:
# --- Processing sample_1 ---
# Found 7724 loose .tif files. Sorting into channel folders...
# Stacking ch2 (1931 planes) -> sample_1_ch2.tif...
# Saved: Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7\sample 1\sample_1_ch2.tif
# Stacking ch1 (1931 planes) -> sample_1_ch1.tif...
# Saved: Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7\sample 1\sample_1_ch1.tif
# Stacking ch0 (1931 planes) -> sample_1_ch0.tif...
# Saved: Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7\sample 1\sample_1_ch0.tif
# Stacking ch3 (1931 planes) -> sample_1_ch3.tif...
# Saved: Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7\sample 1\sample_1_ch3.tif
#
# --- Processing sample_5 ---
# Found 7272 loose .tif files. Sorting into channel folders...
# Stacking ch0 (1818 planes) -> sample_5_ch0.tif...
# Saved: Z:\anatomy_histology\041026_mitopark_retrotracing_lightsheet\Sample 1 5 7\sample 5\sample_5_ch0.tif
# ...

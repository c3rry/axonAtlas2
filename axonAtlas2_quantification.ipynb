# %%
from quantification import calculate_axon_percentage, plot_top_regions, axonDict, volumeExtract, bg_heatmap, calculate_hemisphere_axon_percentage, bg_heatmap_slices
exp_path = r"D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21"
#volume = volumeExtract(exp_path, mode="skeletonize")
volume = r"D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21\downsampled_standard_binned_tiffs\combined_top_5_skeletonize.tif"
print(volume)
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from quantification import calculate_axon_percentage, plot_top_regions, axonDict, volumeExtract, bg_heatmap, calculate_hemisphere_axon_percentage, bg_heatmap_slices
#       2 exp_path = r"D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21"
#       3 #volume = volumeExtract(exp_path, mode="skeletonize")
#
# ImportError: cannot import name 'bg_heatmap_slices' from 'quantification' (d:\axonAtlas2\quantification.py)

# %%
df = calculate_axon_percentage(
    input_volume=volume,
    temp_dir=r"D:\axonAtlas2\experiments\beta_2025-09-10_14-45-50\tmp",
    voxel_size=25,
    output_dir = exp_path
)
df
# Out:
# [INFO] Starting calculation for input: D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21\downsampled_standard_binned_tiffs\combined_top_5_skeletonize.tif
# [INFO] Loading .tif file...
# [INFO] Loaded data with shape: (528, 320, 456)
# [INFO] Loading BrainGlobe Atlas at 25um resolution...
# [INFO] Found 840 named regions in the atlas to process.
# --- Processing region 1/840: root ---
# --- Processing region 2/840: grey ---
# --- Processing region 3/840: CH ---
# --- Processing region 4/840: CTX ---
# --- Processing region 5/840: CTXpl ---
# --- Processing region 6/840: Isocortex ---
# --- Processing region 7/840: FRP ---
# --- Processing region 8/840: FRP1 ---
# --- Processing region 9/840: FRP2/3 ---
# --- Processing region 10/840: FRP5 ---
# --- Processing region 11/840: FRP6a ---
# --- Processing region 12/840: FRP6b ---
# --- Processing region 13/840: MO ---
# --- Processing region 14/840: MOp ---
# --- Processing region 15/840: MOp1 ---
# ...

# %%
df_hemispheres = calculate_hemisphere_axon_percentage(
    input_volume = volume, 
    output_dir = exp_path, 
    voxel_size=25, 
    temp_dir=r"D:\axonAtlas2\experiments\beta_2025-09-10_14-45-50\tmp")
# Out:
# --- Starting Analysis for HEMISPHERE-SPLIT Brain Regions ---
# [INFO] Input volume: D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21\downsampled_standard_binned_tiffs\combined_top_5_skeletonize.tif
# [INFO] Loaded data with shape: (528, 320, 456)
# [INFO] Successfully created hemisphere masks by splitting atlas at midline: 228.
# [INFO] Found 840 base regions to process.
# --- Processing AAA (1/840) ---
# --- Processing ACA (2/840) ---
# --- Processing ACAd (3/840) ---
# --- Processing ACAd1 (4/840) ---
# --- Processing ACAd2/3 (5/840) ---
# --- Processing ACAd5 (6/840) ---
# --- Processing ACAd6a (7/840) ---
# --- Processing ACAd6b (8/840) ---
# --- Processing ACAv (9/840) ---
# --- Processing ACAv1 (10/840) ---
# --- Processing ACAv2/3 (11/840) ---
# --- Processing ACAv5 (12/840) ---
# --- Processing ACAv6a (13/840) ---
# --- Processing ACAv6b (14/840) ---
# --- Processing ACB (15/840) ---
# --- Processing ACVII (16/840) ---
# --- Processing AD (17/840) ---
# ...

# %%
path = exp_path + "/axon_df.csv"
#df = pd.read_csv(path)  
df.to_csv(path, index=False)

# %%
path = exp_path + "/axon_df_hemi.csv"
#df = pd.read_csv(path)  
df_hemispheres.to_csv(path, index=False)

# %%
path = exp_path + "/axon_df_hemi.csv"
df_hemispheres = pd.read_csv(path)

# %%
axon_dict = axonDict(df_hemispheres)
axon_dict
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'VPLpc_right': 10.809102402022756,
#     'SPFp_right': 9.876543209876544,
#     'RR_right': 9.803478653715834,
#     'MRN_right': 8.099840046708794,
#     'dtd_right': 7.894736842105263,
#     'VISpm6b_right': 7.517084282460136,
#     'VISam6a_right': 6.738482695393078,
#     'SPF_right': 6.560392397302269,
#     'ACVII_right': 5.681818181818182,
#     'RN_right': 5.66232119507073,
#     'INC_right': 5.166340508806262,
#     'ZI_right': 4.988197722854762,
#     'PoT_right': 4.694469223907226,
#     'Acs5_right': 4.656319290465632,
#     'MT_right': 4.002911208151383,
#     'RL_right': 3.9268423883808494,
#     'VISpm6a_right': 3.905765654060757,
#     'PPN_right': 3.819017866544983,
#     'POL_right': 3.674460977831764,
#     'GPe_right': 3.6572706220554174,
#     'FF_right': 3.611327617563003,
# ...

# %%
plot_top_regions(df_hemispheres)
# Out:
# d:\axonAtlas2\quantification.py:103: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='percentage', y='acronym', data=top_df, palette='viridis')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x800 with 1 Axes>

# %%
import brainglobe_heatmap as bgh
#bg_heatmap(values = axon_dict, annotate_regions=False, thickness=20)

# Only keep left hemisphere regions
#left_axon_dict = {k: v for k, v in axon_dict.items() if k.endswith('_L')}

bg_heatmap(values=axon_dict, annotate_regions=False, thickness=20, vmin =0, vmax=10, frame=15)
# Out:
# Rendering Frontal view...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x800 with 2 Axes>
# Rendering Sagittal view...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x800 with 2 Axes>
# Rendering Horizontal view...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x800 with 2 Axes>

# %%
bg_heatmap_slices(values=axon_dict, view = "frontal", output_dir=exp_path, annotate_regions=False, vmin =0, vmax=10)
# Out:
# --- Starting Heatmap Slice Generation for 'frontal' view ---
# Output will be saved in: D:\axonAtlas2\experiments\brain5_utsw_downscaled_2025-09-25_15-28-21\heatmap
# Loading atlas to determine slicing range...
# Atlas loaded. Found 528 slices for the 'frontal' view.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bg_heatmap_slices(values=axon_dict, view = "frontal", output_dir=exp_path, annotate_regions=False, vmin =0, vmax=10)
#
# File d:\axonAtlas2\quantification.py:535, in bg_heatmap_slices(values, output_dir, view, vmin, vmax, cmap, atlas_name, annotate_regions)
#     529 # --- Plot Left Hemisphere ---
#     530 hm_left = bgh.Heatmap(
#     531     left_dict, position=position_um, orientation=view, hemisphere='left',
#     532     atlas_name=atlas_name, cmap=cmap, vmin=vmin, vmax=vmax,
#     533     annotate_regions=annotate_regions
# ...
